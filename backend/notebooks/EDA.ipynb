# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Settings
plt.style.use('seaborn-v0_8-whitegrid')
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 1. Load Data

# %%
# TODO: Load dữ liệu từ data/raw/
# df = pd.read_csv('../data/raw/coffee_yield.csv')
# df.head()

# %% [markdown]
# ## 2. Data Overview

# %%
# TODO: Kiểm tra thông tin cơ bản
# print(df.info())
# print(df.describe())

# %% [markdown]
# ## 3. Yield Distribution Analysis

# %%
# TODO: Phân tích phân phối năng suất
# fig, axes = plt.subplots(1, 2, figsize=(12, 5))
# sns.histplot(df['yield'], kde=True, ax=axes[0])
# sns.boxplot(y=df['yield'], ax=axes[1])
# plt.show()

# %% [markdown]
# ## 4. Weather Trends Analysis

# %%
# TODO: Phân tích xu hướng thời tiết theo năm
# - Nhiệt độ trung bình
# - Lượng mưa tổng
# - Số ngày nắng nóng

# %% [markdown]
# ## 5. Correlation Analysis

# %%
# TODO: Phân tích tương quan
# plt.figure(figsize=(12, 8))
# sns.heatmap(df.corr(), annot=True, cmap='coolwarm', center=0)
# plt.title('Correlation Matrix')
# plt.show()

# %% [markdown]
# ## 6. Time Series Analysis

# %%
# TODO: Phân tích time series năng suất qua các năm

# %% [markdown]
# ## 7. Summary & Insights
#
# TODO: Tổng kết các findings từ EDA
